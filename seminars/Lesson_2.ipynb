# %% [markdown]
# # Семинар 2 (неделя 3): Работа с данными

# %%
# Импорт библиотек для работы со статистикой
import pandas as pd
import numpy as np

# Импорт библиотек для построения графиков
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')    #ggplot
# %matplotlib inline

# %% [markdown]
# ## Генерация выборок

# %%
a = np.linspace(-5, 5, 100)
a
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
# ...

# %%
import random

# %%
# возвращает псевдослучайное число от 0.0 до 1.0

random.random()
# Out:
# 0.6720281795736317

# %%
random.seed(2021)
random.random()
# Out:
# 0.8363375023320742

# %%
#  возвращает псевдослучайное вещественное число в диапазоне
random.uniform(0, 20)
# Out:
# 17.166048084163748

# %%
# возвращает псевдослучайное целое число в диапазоне
random.randint(1,27)
# Out:
# 18

# %%
# возвращает случайный элемент из любой последовательности (строки, списка, кортежа)
random.choice('Cheburashka')
# Out:
# 'u'

# %%
#  перемешивает последовательность (изменяется сама последовательность)
b = [1,2,3,4,5,6,7,8,9]
random.shuffle(b)
b
# Out:
# [6, 3, 2, 8, 5, 7, 9, 1, 4]

# %% [markdown]
# #### Генерация произвольного пароля

# %% [markdown]
# Хороший пароль должен быть произвольным и состоять минимум из 6 символов, в нём должны быть цифры, строчные и прописные буквы. Приготовить такой пароль можно по следующему рецепту:

# %%
# Щепотка цифр
str1 = '123456789'

# Щепотка строчных букв
str2 = 'qwertyuiopasdfghjklzxcvbnm'

# %%
# Щепотка прописных букв. Готовится преобразованием str2 в верхний регистр.
str3 = str2.upper()
print(str3)
# Out:
# QWERTYUIOPASDFGHJKLZXCVBNM

# %%
# Соединяем все строки в одну
str4 = str1+str2+str3
print(str4)
# Out:
# 123456789qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM

# %%
# Преобразуем получившуюся строку в список
ls = list(str4)
ls
# Out:
# ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9',
#  'q',
#  'w',
#  'e',
#  'r',
#  't',
#  'y',
#  'u',
#  'i',
#  'o',
#  'p',
#  'a',
#  's',
#  'd',
#  'f',
#  'g',
#  'h',
#  'j',
#  'k',
#  'l',
#  'z',
#  'x',
#  'c',
#  'v',
#  'b',
#  'n',
#  'm',
#  'Q',
#  'W',
#  'E',
#  'R',
#  'T',
#  'Y',
#  'U',
#  'I',
#  'O',
#  'P',
#  'A',
#  'S',
#  'D',
#  'F',
#  'G',
#  'H',
#  'J',
#  'K',
#  'L',
#  'Z',
#  'X',
#  'C',
#  'V',
#  'B',
#  'N',
#  'M']

# %%
# Тщательно перемешиваем список
random.shuffle(ls)
ls
# Out:
# ['a',
#  '2',
#  'e',
#  'i',
#  'W',
#  't',
#  'G',
#  'k',
#  '6',
#  'X',
#  'f',
#  'l',
#  'F',
#  '3',
#  'U',
#  'J',
#  'h',
#  'K',
#  '1',
#  '9',
#  'B',
#  'q',
#  'T',
#  'P',
#  'E',
#  'Y',
#  's',
#  'S',
#  'v',
#  'N',
#  'b',
#  'u',
#  'y',
#  'I',
#  'j',
#  'g',
#  'd',
#  'n',
#  'o',
#  'z',
#  'R',
#  'r',
#  '8',
#  'x',
#  'H',
#  'm',
#  'Z',
#  'M',
#  'Q',
#  'A',
#  'O',
#  '7',
#  'D',
#  '4',
#  'L',
#  'V',
#  'w',
#  'C',
#  '5',
#  'c',
#  'p']

# %%
# Тщательно перемешиваем список
random.shuffle(ls)
ls
# Out:
# ['N',
#  'o',
#  '2',
#  'd',
#  'X',
#  'J',
#  'u',
#  '9',
#  'q',
#  'E',
#  '3',
#  'B',
#  'c',
#  'D',
#  'M',
#  'h',
#  'm',
#  '4',
#  's',
#  'e',
#  'j',
#  '8',
#  'O',
#  'L',
#  'F',
#  'I',
#  'Z',
#  'P',
#  'i',
#  '5',
#  'f',
#  'Q',
#  't',
#  'y',
#  'W',
#  'k',
#  'r',
#  'x',
#  'g',
#  'v',
#  'a',
#  'T',
#  'G',
#  '1',
#  'b',
#  'p',
#  'z',
#  'C',
#  '7',
#  'w',
#  'l',
#  'V',
#  'K',
#  'A',
#  'Y',
#  'S',
#  'R',
#  '6',
#  'n',
#  'U',
#  'H']

# %%
# Извлекаем из списка 12 произвольных значений
psw = ''.join([random.choice(ls) for x in range(12)])

# Пароль готов
print(psw)
# Out:
# 2gItfOWhmgHt

# %%
# то же самое, но короче:

print(''.join([random.choice(list('123456789qwertyuiopasdfghjklzxcvbnmQWERTYUIOPASDFGHJKLZXCVBNM')) for x in range(12)]))
# Out:
# odeHlEfnhwms

# %% [markdown]
# ## Анализ таблиц

# %% [raw]
# # Расход транспортного средства в зависимости от его характеристик
# https://archive.ics.uci.edu/ml/datasets/auto+mpg

# %%
# Чтение датасета с помощью pandas
CarsDS = pd.read_csv('mpg.csv', sep=",")

# Демонстрация первых 5 строк таблицы
CarsDS.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
CarsDS.shape
# Out:
# (398, 9)

# %%
CarsDS.size
# Out:
# 3582

# %% [markdown]
# Отображаем нужные столбцы разными способами:

# %%
CarsDS[['mpg', 'cylinders', 'displacement']]
# Out:
#       mpg  cylinders  displacement
# 0    18.0          8         307.0
# 1    15.0          8         350.0
# 2    18.0          8         318.0
# 3    16.0          8         304.0
# 4    17.0          8         302.0
# ..    ...        ...           ...
# 393  27.0          4         140.0
# 394  44.0          4          97.0
# 395  32.0          4         135.0
# 396  28.0          4         120.0
# 397  31.0          4         119.0
#
# [398 rows x 3 columns]

# %%
parameters = ['mpg', 'displacement', 'horsepower', 'weight', 'acceleration']
CarsDS[parameters]
# Out:
#       mpg  displacement  horsepower  weight  acceleration
# 0    18.0         307.0       130.0    3504          12.0
# 1    15.0         350.0       165.0    3693          11.5
# 2    18.0         318.0       150.0    3436          11.0
# 3    16.0         304.0       150.0    3433          12.0
# 4    17.0         302.0       140.0    3449          10.5
# ..    ...           ...         ...     ...           ...
# 393  27.0         140.0        86.0    2790          15.6
# 394  44.0          97.0        52.0    2130          24.6
# 395  32.0         135.0        84.0    2295          11.6
# 396  28.0         120.0        79.0    2625          18.6
# 397  31.0         119.0        82.0    2720          19.4
#
# [398 rows x 5 columns]

# %%
CarsDS.iloc[:, [4, 3, 0]]
# Out:
#      weight  horsepower   mpg
# 0      3504       130.0  18.0
# 1      3693       165.0  15.0
# 2      3436       150.0  18.0
# 3      3433       150.0  16.0
# 4      3449       140.0  17.0
# ..      ...         ...   ...
# 393    2790        86.0  27.0
# 394    2130        52.0  44.0
# 395    2295        84.0  32.0
# 396    2625        79.0  28.0
# 397    2720        82.0  31.0
#
# [398 rows x 3 columns]

# %%
CarsDS.iloc[:, 2:5]
# Out:
#      displacement  horsepower  weight
# 0           307.0       130.0    3504
# 1           350.0       165.0    3693
# 2           318.0       150.0    3436
# 3           304.0       150.0    3433
# 4           302.0       140.0    3449
# ..            ...         ...     ...
# 393         140.0        86.0    2790
# 394          97.0        52.0    2130
# 395         135.0        84.0    2295
# 396         120.0        79.0    2625
# 397         119.0        82.0    2720
#
# [398 rows x 3 columns]

# %%
CarsDS.mpg.value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 34.2     1
# 38.1     1
# 37.2     1
# 32.1     1
# 32.7     1
# Name: mpg, Length: 129, dtype: int64

# %%
CarsDS.describe(include = 'object')
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year         lpk         env        mass
# count    398.000000  398.000000  398.000000  398.000000  398.000000
# mean      15.568090   76.010050   11.214233    3.169682    1.347385
# std        2.757689    3.697627    3.902491    1.708677    0.384127
# min        8.000000   70.000000    5.048053    1.114320    0.731657
# ...

# %%
CarsDS.describe(include = 'object')
# Out:
#        origin        name
# count     398         398
# unique      3         305
# top       usa  ford pinto
# freq      249           6

# %%
CarsDS.origin.value_counts(dropna=False)
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
# shift+tab - свойства и параметры функции

CarsDS.name.value_counts(dropna=False)
# Out:
# ford pinto                      6
# ford maverick                   5
# toyota corolla                  5
# amc matador                     5
# peugeot 504                     4
#                                ..
# volkswagen 1131 deluxe sedan    1
# dodge magnum xe                 1
# plymouth volare premier v8      1
# chevrolet vega 2300             1
# datsun 810                      1
# Name: name, Length: 305, dtype: int64

# %% [markdown]
# - Уникальные значения кол-ва цилиндров в порядке возрастания

# %%
lst = list(CarsDS.cylinders.unique())
lst.sort(reverse=False)
lst
# Out:
# [3, 4, 5, 6, 8]

# %% [markdown]
# - Показать 10% автомобилей, которые наиболее часто встречаются в выборке - 10% самых популярных авто в выборке

# %%
q = CarsDS.name.value_counts().quantile(0.9)
q
# Out:
# 2.0

# %%
CarsDS.name.value_counts()
# Out:
# ford pinto                      6
# ford maverick                   5
# toyota corolla                  5
# amc matador                     5
# peugeot 504                     4
#                                ..
# volkswagen 1131 deluxe sedan    1
# dodge magnum xe                 1
# plymouth volare premier v8      1
# chevrolet vega 2300             1
# datsun 810                      1
# Name: name, Length: 305, dtype: int64

# %%
list(CarsDS.name.value_counts()[CarsDS.name.value_counts()>q].index)
# Out:
# ['ford pinto',
#  'ford maverick',
#  'toyota corolla',
#  'amc matador',
#  'peugeot 504',
#  'chevrolet chevette',
#  'amc hornet',
#  'chevrolet impala',
#  'amc gremlin',
#  'toyota corona',
#  'chevrolet caprice classic',
#  'plymouth duster',
#  'dodge colt',
#  'plymouth fury iii',
#  'honda civic',
#  'pontiac catalina',
#  'volkswagen dasher',
#  'chevrolet citation',
#  'ford galaxie 500',
#  'chevrolet nova',
#  'ford gran torino',
#  'chevrolet vega']

# %% [markdown]
# Переводим единицы измерений в понятные величины:

# %%
# mpg --> liters per 100 km
kmpm = 1.609 #km
lpg = 3.785 #l
cmpinch = 2.54 #cm
kgplbs = 0.4536 #kg

CarsDS['lpk'] = lpg * 100 / (CarsDS['mpg'] * kmpm) # литр на 100 км
CarsDS['env'] = CarsDS['displacement'] * cmpinch**3 / 1000 # объем двигателя в литрах
CarsDS['mass'] = CarsDS['weight'] * kgplbs / 1000 # масса в тоннах

# %%
CarsDS['lpk']
# Out:
# 0      13.068849
# 1      15.682619
# 2      13.068849
# 3      14.702455
# 4      13.837605
#          ...
# 393     8.712566
# 394     5.346347
# 395     7.351227
# 396     8.401403
# 397     7.588364
# Name: lpk, Length: 398, dtype: float64

# %%
CarsDS
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name        lpk       env  \
# ...

# %% [markdown]
# ## Группировка данных

# %% [markdown]
# - Показать средний и медианный расход автомобилей с 6 циллиндрами

# %%
CarsDS['lpk'][CarsDS.cylinders==6].mean()
# Out:
# 12.107380341315721

# %%
CarsDS['lpk'][CarsDS.cylinders==6].median()
# Out:
# 12.381014687121782

# %% [markdown]
# - Показать средний и медианный расход автомобилей в зависимости от количества циллиндров

# %%
CarsDS.groupby(['cylinders'])['lpk'].agg(['mean', 'median'])
# Out:
#                 mean     median
# cylinders
# 3          11.579233  11.661188
# 4           8.334152   8.327289
# 5           9.104049   9.261389
# 6          12.107380  12.381015
# 8          16.237366  16.802806

# %% [markdown]
# - Показать средний и медианный расход автомобилей в зависимости от количества циллиндров и места производства

# %%
CarsDS.groupby(['cylinders', 'origin'])['lpk'].agg(['mean', 'median'])
# Out:
#                        mean     median
# cylinders origin
# 3         japan   11.579233  11.661188
# 4         europe   8.671297   8.712566
#           japan    7.677219   7.351227
#           usa      8.668712   8.712566
# 5         europe   9.104049   9.261389
# 6         europe  12.569498  14.047265
#           japan   10.168593  10.206663
#           usa     12.239600  12.381015
# 8         usa     16.237366  16.802806

# %%
CarsDS.groupby(['cylinders', 'origin'])['lpk'].agg(['mean', 'median']).reset_index().reset_index()
# Out:
#    index  cylinders  origin       mean     median
# 0      0          3   japan  11.579233  11.661188
# 1      1          4  europe   8.671297   8.712566
# 2      2          4   japan   7.677219   7.351227
# 3      3          4     usa   8.668712   8.712566
# 4      4          5  europe   9.104049   9.261389
# 5      5          6  europe  12.569498  14.047265
# 6      6          6   japan  10.168593  10.206663
# 7      7          6     usa  12.239600  12.381015
# 8      8          8     usa  16.237366  16.802806

# %%
CarsDS.groupby(['cylinders', 'origin'])['lpk'].agg(['mean', 'median']).reset_index().reset_index(drop=True)
# Out:
#    cylinders  origin       mean     median
# 0          3   japan  11.579233  11.661188
# 1          4  europe   8.671297   8.712566
# 2          4   japan   7.677219   7.351227
# 3          4     usa   8.668712   8.712566
# 4          5  europe   9.104049   9.261389
# 5          6  europe  12.569498  14.047265
# 6          6   japan  10.168593  10.206663
# 7          6     usa  12.239600  12.381015
# 8          8     usa  16.237366  16.802806

# %%
CarsDS.groupby(['cylinders', 'origin'])['lpk'].agg(['mean', 'median']).reset_index(drop=True)
# Out:
#         mean     median
# 0  11.579233  11.661188
# 1   8.671297   8.712566
# 2   7.677219   7.351227
# 3   8.668712   8.712566
# 4   9.104049   9.261389
# 5  12.569498  14.047265
# 6  10.168593  10.206663
# 7  12.239600  12.381015
# 8  16.237366  16.802806

# %%
CarsDS.model_year.sort_values(ascending=True).unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
CarsDS.model_year.sort_values().nunique()
# Out:
# 13

# %% [markdown]
# ## Методы визуализации данных для анализа

# %%
sns.pairplot(CarsDS.iloc[:, 0:6], height = 2.5, kind = 'scatter');

# %%
new_par = ['cylinders', 'horsepower', 'acceleration', 'lpk', 'env', 'mass']
sns.pairplot(CarsDS[new_par], hue = 'cylinders', height = 2.5, kind = 'scatter', palette = 'bright');

# %% [raw]
# Функция jointplot() показывает совместное распределение по двум переменным. Она имеет параметр kind который может принимать следующие значения:
#
# “scatter” - диаграмма рассеяния
# “reg” - модели полиномиальной регрессии для изучения простых видов нелинейных трендов в наборе данных
# “resid” - отображает отклонения элементов исходного набора данных от регрессионной модели, построенной по ним, в виде диаграммы рассеяния.
# “kde” - оценка плотности ядра (KDE) — это способ оценки функции плотности вероятности непрерывной случайной величины. Используется для непараметрического анализа.
# “hex” - гексагональное объединение используется в двумерном анализе данных, когда данные имеют небольшую плотность, т.е. когда данные очень разбросаны и их трудно анализировать с помощью диаграмм рассеяния.

# %%
sns.jointplot(x = 'mass', y = 'lpk', data = CarsDS[new_par], kind='scatter')

# %% [raw]
# Передав «reg» параметру kind, мы можем добавить линию регрессии и добавить графики kde к гистограммам по сторонам.

# %%
sns.jointplot(x = 'mass', y = 'lpk', data = CarsDS[new_par], kind='reg')

# %%
sns.jointplot(x = 'mass', y = 'lpk', data = CarsDS[new_par], kind='kde')

# %%
sns.jointplot(x = 'mass', y = 'lpk', data = CarsDS[new_par], kind='resid')

# %%
sns.jointplot(x = 'mass', y = 'lpk', data = CarsDS[new_par], kind='hex')

# %% [markdown]
# ## Зависимость и независимость данных: ковариация и корреляция

# %% [markdown]
# - Ковариа́ция (корреляционный момент, ковариационный момент) — в теории вероятностей и математической статистике мера линейной зависимости двух случайных величин.
# - Ковариация - это мера того, как изменения одной переменной связаны с изменениями второй переменной.
# - В частности, ковариация измеряет степень, в которой две переменные связаны линейно.
#
# - Коэффициент корреляции - это ковариация двух случайных величин, поделенная на среднее геометрическое их дисперсий; он принимает значения от -1 до 1, и этим удобен. Следует помнить, что наличие связи между значениями двух случайных величин (корреляции) не означает причинно-следственной связи между самими величинами.
#
#
#
#
#
# $$\rho_{xy} = \frac{Cov(x, y)}{\sigma_x \sigma_y} = \frac{ \overline{x \cdot y} - \overline{x} \cdot \overline{y} }{\sigma_x \sigma_y}$$

# %%
X = CarsDS['mass']
Y = CarsDS['lpk']

X_m = X.mean()
Y_m = Y.mean()

X_s = X.std()
Y_s = Y.std()

P_xy = ( (X*Y).mean() - X_m * Y_m) / ( X_s * Y_s )

P_xy
# Out:
# 0.8829943924178684

# %%
from scipy import stats


x = CarsDS['mass']
y = CarsDS['lpk']
stats.pearsonr(x, y)[0]
# Out:
# 0.8852185596531806

# %%
CarsDS[new_par].corr(method='pearson')
# Out:
#               cylinders  horsepower  acceleration       lpk       env  \
# cylinders      1.000000    0.842983     -0.505419  0.839278  0.950721
# horsepower     0.842983    1.000000     -0.689196  0.854809  0.897257
# acceleration  -0.505419   -0.689196      1.000000 -0.455750 -0.543684
# lpk            0.839278    0.854809     -0.455750  1.000000  0.866631
# env            0.950721    0.897257     -0.543684  0.866631  1.000000
# mass           0.896017    0.864538     -0.417457  0.885219  0.932824
#
#                   mass
# cylinders     0.896017
# horsepower    0.864538
# acceleration -0.417457
# lpk           0.885219
# env           0.932824
# mass          1.000000

# %%
stats.spearmanr(x,y).correlation
# Out:
# 0.8749473981990712

# %%
CarsDS[new_par].corr(method='spearman')
# Out:
#               cylinders  horsepower  acceleration       lpk       env  \
# cylinders      1.000000    0.816188     -0.474189  0.821864  0.911876
# horsepower     0.816188    1.000000     -0.658142  0.853616  0.876171
# acceleration  -0.474189   -0.658142      1.000000 -0.438677 -0.496512
# lpk            0.821864    0.853616     -0.438677  1.000000  0.855692
# env            0.911876    0.876171     -0.496512  0.855692  1.000000
# mass           0.873314    0.878819     -0.404550  0.874947  0.945986
#
#                   mass
# cylinders     0.873314
# horsepower    0.878819
# acceleration -0.404550
# lpk           0.874947
# env           0.945986
# mass          1.000000

# %% [markdown]
# Разница между корреляцией Пирсона и корреляцией Спирмена состоит в том, что Пирсон наиболее подходит для измерений, взятых из интервальной шкалы, тогда как Спирман больше подходит для измерений, взятых из порядковых шкал.

# %%
sns.set(font_scale=1.2)
plt.subplots(figsize=(7, 7))
sns.heatmap(CarsDS[new_par].corr(method='pearson'),
            square = True, 
            annot = True, 
            fmt=".2f", 
            linewidths=0.1, 
            cmap="coolwarm");

# %% [markdown]
# Примеры ложных корреляций:
# http://www.tylervigen.com/spurious-correlations
